# %%
from utils.graph import Grafo
from heapq import heapify, heappop, heappush

# %%
grafo = Grafo.load_pickled_graph("../graph/graph.pkl")

# %%
def djisktra(grafo: Grafo, initial_node) -> dict:
    distances = distances = {node: float("inf") for node in grafo.adj_list}
    distances[initial_node] = 0

    # inicio priority queue
    pq = [(0, initial_node)]
    heapify(pq)

    visited = set()

    while pq:
        current_distance, current_node = heappop(
            pq
        )  # pega o no com a menor distancia
        if current_node in visited:
            continue
        visited.add(current_node)

        for neighbor, weight in grafo.adj_list[current_node]:
            # Calcula distancia do no atual ate o vizinho
            tentative_distance = current_distance + weight
            if tentative_distance < distances[neighbor]:
                #se achar distancia menor que atual coloca na lista de distancias
                distances[neighbor] = tentative_distance
                heappush(pq, (tentative_distance, neighbor))

    return distances

# %%
distancias = djisktra(grafo, 'jons@amerexenergy.com')
distancias
# Out:
# {'jons@amerexenergy.com': 0,
#  'sandra.f.brawner@enron.com': 16,
#  'enron.announcements@enron.com': inf,
#  'all.houston@enron.com': inf,
#  'sandra.brawner@enron.com': 9,
#  'kennethbrawner@msn.com': 4,
#  'perfmgmt@enron.com': inf,
#  'jared.kaiser@enron.com': 6,
#  'kam.keiser@enron.com': 8,
#  'scott.neal@enron.com': 5,
#  'michael.garberding@enron.com': 19,
#  'cris.sherman@enron.com': 9,
#  'morris.clark@enron.com': 22,
#  'teresa.bushman@enron.com': 19,
#  'william.bradford@enron.com': 22,
#  'ragan.bond@enron.com': 10,
#  'outlook.team@enron.com': 9,
#  'ann.vaughn@enron.com': 12,
#  'wilson.barbee@enron.com': 12,
#  'estalee.russi@enron.com': 12,
#  'felicia.beal@enron.com': 12,
#  'fran.fagan@enron.com': 9,
#  'gary.smith@enron.com': 12,
#  'jerry.harkreader@enron.com': 12,
#  'john.anderson@enron.com': 10,
#  'jorge.olivares@enron.com': 12,
#  'kristin.passmore@enron.com': 12,
#  'leesa.hutcherson@enron.com': 12,
#  'michele.denby@enron.com': 12,
#  'miranda.southard@enron.com': 12,
#  'renee.pena@enron.com': 12,
#  'rita.houston@enron.com': 12,
#  'roger.sumlin@enron.com': 12,
#  'wilford.dodd@enron.com': 12,
#  'william.keeney@enron.com': 12,
#  'brad.alford@enron.com': 12,
#  'bruce.golden@enron.com': 12,
#  'bryan.williams@enron.com': 12,
#  'carl.tricoli@enron.com': 7,
#  'christopher.coffman@enron.com': 12,
#  'chu.wang@enron.com': 12,
#  'charles.ward@enron.com': 12,
#  'w.duran@enron.com': 12,
#  'david.marks@enron.com': 11,
#  'eric.rhodes@enron.com': 12,
#  'farouk.lalji@enron.com': 12,
#  'george.schaefer@enron.com': 12,
#  'greg.blair@enron.com': 12,
#  'greg.martin@enron.com': 11,
#  'jeff.hoover@enron.com': 12,
#  'john.moore@enron.com': 12,
#  'lisa.zarsky@enron.com': 10,
#  'mario.alonso@enron.com': 12,
#  'michael.miller@enron.com': 12,
#  'mitch.robinson@enron.com': 9,
#  'naveed.ahmed@enron.com': 12,
#  'paulita.olvera@enron.com': 12,
#  'tina.holcombe@enron.com': 10,
#  'tina.rode@enron.com': 9,
#  'tosha.henderson@enron.com': 12,
#  'andrea.ring@enron.com': 5,
#  'brad.mckay@enron.com': 6,
#  'chris.germany@enron.com': 6,
#  'judy.townsend@enron.com': 6,
#  'kimberly.bates@enron.com': 8,
#  'peter.keavey@enron.com': 11,
#  'scott.goodell@enron.com': 6,
#  'sean.boyle@enron.com': 10,
#  'susan.pereira@enron.com': 11,
#  'victoria.versen@enron.com': 7,
#  'vladi.pimenov@enron.com': 6,
#  'derek.anderson@enron.com': 12,
#  'susan.huston@enron.com': 12,
#  'burak.hurbas@enron.com': 12,
#  'colin.crowley@enron.com': 12,
#  'lisa.rizzo@enron.com': 12,
#  'richard.johnson@enron.com': 12,
#  'sandra.torres@enron.com': 12,
#  'angela.stie@enron.com': 12,
#  'armando.lira@enron.com': 12,
#  "audry.o'toole@enron.com": 12,
#  'beverly.filer@enron.com': 12,
#  'helen.jeschke@enron.com': 12,
#  'john.harrison@enron.com': 12,
#  'kristi.louthan@enron.com': 12,
#  'michael.philips@enron.com': 12,
#  'peggy.rathmell@enron.com': 12,
#  'robert.jr@enron.com': 12,
#  'shannon.cobb@enron.com': 12,
#  'sharon.stringfellow@enron.com': 12,
#  'valarie.curry@enron.com': 12,
#  'pama9@flash.net': 16,
#  'brian.hoskins@enron.com': 14,
#  's.schnitzer@worldnet.att.net': 12,
#  'kennethbrawner@email.msn.com': 25,
#  'jeffrey.shankman@enron.com': 22,
#  'all.worldwide@enron.com': inf,
#  'jesus.guerra@enron.com': 10,
#  'parking.transportation@enron.com': 12,
#  'jons@amerexyenergy.com': 13,
#  'airam.arteaga@enron.com': 8,
#  'robin.barbe@enron.com': 8,
#  'john.taylor@enron.com': 9,
#  'dick.jenkins@enron.com': 11,
#  'scott.hendrickson@enron.com': 6,
#  'dan.junek@enron.com': 11,
#  'tammi.depaolis@enron.com': 10,
#  'rrussin@natsource.com': 12,
#  'kimberly.brown@enron.com': 13,
#  'ina.rangel@enron.com': 9,
#  'colleen.sullivan@enron.com': 10,
#  'phillip.allen@enron.com': 12,
#  'thomas.martin@enron.com': 12,
#  'greg.mcclendon@enron.com': 12,
#  'kimberly.olinger@enron.com': 11,
#  'hunter.shively@enron.com': 12,
#  'elsa.villarreal@enron.com': 12,
#  'keith.holst@enron.com': 5,
#  'kate.fraser@enron.com': 12,
#  'andrew.lewis@enron.com': 12,
#  'john.lavorato@enron.com': 5,
#  'mike.grigsby@enron.com': 6,
#  'martin.cuilla@enron.com': 6,
#  'deirdre.mccaffrey@enron.com': 11,
#  'sylvia.pollan@enron.com': 12,
#  'geoff.storey@enron.com': 5,
#  'louis.dicarlo@enron.com': 9,
#  'ksmalek@aep.com': 9,
#  'tk.lohman@enron.com': 5,
#  'john.griffith@enron.com': 5,
#  'russ.severson@enron.com': 9,
#  'scott.mills@enron.com': 10,
#  'jeffrey.gossett@enron.com': 8,
#  'david.delainey@enron.com': 12,
#  'louise.kitchen@enron.com': 5,
#  'stouchstone@natsource.com': 13,
#  'matthew.fleming@enron.com': 12,
#  'waltonw@epenergy.com': 12,
#  'tricia.spence@enron.com': 12,
#  'kennethbrawner@mns.com': 14,
#  'jons@amerexenergy': 17,
#  'jons@amerex.com': 4,
#  'byoung@prebon.com': 21,
#  'public.relations@enron.com': inf,
#  'eligible.employees@enron.com': inf,
#  'sschnitz@jcpenney.com': 3,
#  'paulla@maritz.com': 3,
#  'robert.k.rodriguez@db.com': 3,
#  'lmorris1@pclient.ml.com': 3,
#  'gee_ruiz@hotmail.com': 3,
#  'ddunnavant@reliantenergy.com': 3,
#  'aertel@evomarkets.com': 3,
#  'jrschnitzer@hotmail.com': 3,
#  'prebonenergy@corporateecards.com': inf,
#  'sarah.mulholland@enron.com': 10,
#  'maureen.smith@enron.com': 8,
#  'tom.donohoe@enron.com': 4,
#  'kelli.stevens@enron.com': 6,
#  'jason.williams@enron.com': 12,
#  'patrice.mims@enron.com': 12,
#  'kevin.ruscitti@enron.com': 6,
#  'jay.reitmeyer@enron.com': 6,
#  'kenneth.shulklapper@enron.com': 12,
#  'matthew.lenhart@enron.com': 6,
#  'steven.south@enron.com': 12,
#  'jane.tholt@enron.com': 12,
#  'monique.sanchez@enron.com': 6,
#  'carey.metz@enron.com': 12,
#  'stacey.neuweiler@enron.com': 12,
#  'liz.bellamy@enron.com': 12,
#  'jim.schwieger@enron.com': 5,
#  'daren.farmer@enron.com': 11,
#  'lauri.allen@enron.com': 12,
#  'edward.gottlob@enron.com': 12,
#  'gary.lamphier@enron.com': 11,
#  'danny.conner@enron.com': 12,
#  'john.arnold@enron.com': 6,
#  'mike.maggi@enron.com': 5,
#  'larry.may@enron.com': 5,
#  'mfortuna@tfsbrokers.com': 12,
#  'jennifer.fraser@enron.com': 9,
#  'jennifer.shipos@enron.com': 9,
#  'russell.diamond@enron.com': 9,
#  'kenny.soignet@enron.com': inf,
#  'berney.aucoin@enron.com': inf,
#  'janet.dietrich@enron.com': 9,
#  'julie.gomez@enron.com': inf,
#  'joseph.hrgovcic@enron.com': inf,
#  'calvin.johnson@enron.com': inf,
#  'heather.kendall@enron.com': inf,
#  'jean.mrha@enron.com': 6,
#  'chris.foster@enron.com': inf,
#  'fred.lagrasta@enron.com': 6,
#  'michael.cowan@enron.com': 6,
#  'chris.connelly@enron.com': inf,
#  'daniel.diamond@enron.com': 4,
#  'per.sekse@enron.com': inf,
#  'lee.papayoti@enron.com': inf,
#  'liz.taylor@enron.com': 10,
#  'marc.horowitz@enron.com': inf,
#  'sunil.dalal@enron.com': inf,
#  'clayton.vernon@enron.com': 13,
#  'frank.hayden@enron.com': 10,
#  'kimberly.hillis@enron.com': 9,
#  'elsa.piekielniak@enron.com': inf,
#  'sachin.gandhi@enron.com': inf,
#  'paul.lucci@enron.com': inf,
#  'caroline.abramo@enron.com': inf,
#  'russell.dyk@enron.com': inf,
#  'paul.bieniawski@enron.com': 24,
#  'gregory.schockling@enron.com': inf,
#  'mog.heu@enron.com': 9,
#  'enron.states@enron.com': inf,
#  'lucy.marshall@enron.com': 12,
#  'lesli.campbell@enron.com': 13,
#  'afinch@natsource.com': 13,
#  'melba.lozano@enron.com': 9,
#  'clement.abrams@enron.com': 19,
#  'donna.lowry@enron.com': 22,
#  'jeffrey.hodge@enron.com': 19,
#  'joseph.deffner@enron.com': 12,
#  'molly.harris@enron.com': 22,
#  'pushkar.shahi@enron.com': 22,
#  'sara.shackleton@enron.com': 19,
#  'brent.spiller@enron.com': 15,
#  'clare.santana@gte.net': 12,
#  'mathew.gimble@enron.com': inf,
#  'david.fairley@enron.com': 10,
#  'ozzie.pagan@enron.com': 10,
#  'rusty.stevens@enron.com': inf,
#  'gautam.gupta@enron.com': 6,
#  'stephanie.miller@enron.com': 9,
#  'john.hodge@enron.com': 7,
#  'ed.mcmichael@enron.com': 9,
#  'herman.manis@enron.com': inf,
#  'sheila.tweed@enron.com': 11,
#  'barton.clark@enron.com': 19,
#  'mike.coleman@enron.com': inf,
#  'michael.nanny@enron.com': inf,
#  'richard.bickings@enron.com': inf,
#  'walter.coffer@enron.com': inf,
#  'lisa.bills@enron.com': 19,
#  'kay.mann@enron.com': 18,
#  'patrick.maloy@enron.com': inf,
#  'ted.ryan@enron.com': inf,
#  'dave.kellermeyer@enron.com': inf,
#  'george.mccormick@enron.com': 10,
#  'webb.jennings@enron.com': inf,
#  'karen.carter@enron.com': inf,
#  'kevin.presto@enron.com': 6,
#  'rogers.herndon@enron.com': 5,
#  'office.chairman@enron.com': inf,
#  'kimat.singla@enron.com': 7,
#  'enron.mail@enron.com': inf,
#  'megan.angelos@enron.com': 12,
#  'all.employees@enron.com': inf,
#  'houston.report@enron.com': inf,
#  'lcjo@dynegy.com': 4,
#  'adam.johnson@enron.com': 9,
#  'jennifer.denny@enron.com': 9,
#  'david.forster@enron.com': 7,
#  'torrey.moorer@enron.com': 9,
#  'matt.motsinger@enron.com': 9,
#  'savita.puthigai@enron.com': 10,
#  'jennifer.rosado@enron.com': 9,
#  'tammie.schoppe@enron.com': 9,
#  'craig.taylor@enron.com': 6,
#  'andy.zipper@enron.com': 7,
#  'bharat.khanna@enron.com': inf,
#  'mike.roberts@enron.com': inf,
#  'chris.gaskill@enron.com': 7,
#  'gasfundy@enron.com': inf,
#  'lucy.ortiz@enron.com': 10,
#  'jeff.andrews@enron.com': inf,
#  'agustin.perez@enron.com': 10,
#  'enron.services@enron.com': inf,
#  'amanda.rybarski@enron.com': 9,
#  'chuck.ames@enron.com': 7,
#  'jonathan.mckay@enron.com': 4,
#  'f..brawner@enron.com': 3,
#  '40enron@enron.com': 11,
#  'All_ENA_EGM_EIM@ENRON': 14,
#  'eric.boyt@enron.com': 9,
#  'sonya.johnson@enron.com': inf,
#  'rudy.acevedo@enron.com': 10,
#  'suzanne.adams@enron.com': inf,
#  'fraser.allen@enron.com': inf,
#  'denis.bajolle@enron.com': 10,
#  'jozsef.balogh@enron.com': inf,
#  'don.baughman@enron.com': 6,
#  'david.baumbach@enron.com': 7,
#  'gregor.baumerich@enron.com': inf,
#  'kimberlee.bennick@enron.com': 19,
#  'corry.bentley@enron.com': 8,
#  'jason.biever@enron.com': 9,
#  'justin.boyd@enron.com': inf,
#  'greg.brazaitis@enron.com': inf,
#  'rebecca.cantrell@enron.com': 17,
#  'michelle.cash@enron.com': 11,
#  'jon.chapman@enron.com': inf,
#  'winston.cheng@enron.com': inf,
#  'dustin.collins@enron.com': 44,
#  'harry.collins@enron.com': 19,
#  'kayne.coulter@enron.com': 9,
#  'natasha.danilochkina@enron.com': inf,
#  'derek.davies@enron.com': 6,
#  'paul.dawson@enron.com': inf,
#  'paul.devries@enron.com': inf,
#  'trang.dinh@enron.com': inf,
#  'john.disturnal@enron.com': 6,
#  'jeff.donahue@enron.com': 11,
#  'mary.dove@enron.com': inf,
#  'lon.draper@enron.com': 9,
#  'ian.dundas@enron.com': inf,
#  'jarek.dybowski@enron.com': 11,
#  'david.eubanks@enron.com': inf,
#  'farzad.farhangnia@enron.com': inf,
#  'jose.figueira@enron.com': inf,
#  'genia.fitzgerald@enron.com': 19,
#  'shawna.flynn@enron.com': 21,
#  'eric.gillaspie@enron.com': 19,
#  'hector.godoy@enron.com': inf,
#  'joe.gold@enron.com': 10,
#  'john.gorman@enron.com': inf,
#  'jin.guo@enron.com': inf,
#  'mary.hain@enron.com': 11,
#  'jai.hawker@enron.com': inf,
#  'mary.heinitz@enron.com': 13,
#  'jenny.helton@enron.com': inf,
#  'jonathan.hoff@enron.com': 10,
#  'erik.hokmark@enron.com': inf,
#  'jim.homco@enron.com': 22,
#  'mary.hopkins@enron.com': inf,
#  'dan.hyvl@enron.com': 19,
#  'neil.jackson@enron.com': inf,
#  'victoria.johnson@enron.com': inf,
#  'deb.korkmas@enron.com': 13,
#  'dean.laurent@enron.com': 22,
#  'doug.leach@enron.com': inf,
#  'elsie.lew@enron.com': 7,
#  'miles.lidsey@enron.com': inf,
#  'homer.lin@enron.com': inf,
#  'gretchen.lotz@enron.com': 9,
#  'derek.lynn@enron.com': inf,
#  'dan.lyons@enron.com': 19,
#  'iona.maclean@enron.com': inf,
#  'posey.martinez@enron.com': 22,
#  'elizabeth.mccarthy@enron.com': inf,
#  'kelly.mccoy@enron.com': inf,
#  'fred.mitro@enron.com': inf,
#  'eric.moon@enron.com': 10,
#  'janet.moore@enron.com': 21,
#  'janice.moore@enron.com': 19,
#  'russell.murrell@enron.com': inf,
#  'gerald.nemec@enron.com': 13,
#  'florian.neubauer@enron.com': inf,
#  'matthew.nicholas@enron.com': inf,
#  'linda.noske@enron.com': 19,
#  'jiri.novotny@enron.com': inf,
#  'mary.ogden@enron.com': 14,
#  'grant.oh@enron.com': 8,
#  'john.oliver@enron.com': inf,
#  'jitendra.patel@enron.com': 10,
#  'gregg.penman@enron.com': 11,
#  'debra.perlingiere@enron.com': 19,
#  'john.peyton@enron.com': inf,
#  'david.redmond@enron.com': inf,
#  'louis.redshaw@enron.com': inf,
#  'cooper.richey@enron.com': 9,
#  'michael.rosen@enron.com': inf,
#  'jivko.savov@enron.com': 19,
#  'l..schrab@enron.com': 8,
#  'eric.shaw@enron.com': 11,
#  'tom.shelton@enron.com': 13,
#  'john.sherriff@enron.com': 11,
#  'gareth.simpson@enron.com': inf,
#  'michael.slade@enron.com': inf,
#  'ian.sloman@enron.com': inf,
#  'fletcher.sturm@enron.com': 6,
#  'john.suarez@enron.com': 7,
#  'fred.tan@enron.com': inf,
#  'hala.tayyarah@enron.com': inf,
#  'garrett.tripp@enron.com': 9,
#  'steve.vavrik@enron.com': inf,
#  'robert.walker@enron.com': 19,
#  'stacey.white@enron.com': 11,
#  'chris.wiebe@enron.com': inf,
#  'r..wiesepape@enron.com': inf,
#  'doug.wood@enron.com': inf,
#  'kay.young@enron.com': 19,
#  'john.zufferli@enron.com': 6,
#  'k..allen@enron.com': 5,
#  'f..keavey@enron.com': 4,
#  'a..martin@enron.com': 6,
#  'w..pereira@enron.com': 6,
#  's..shively@enron.com': 6,
#  'tara.sweitzer@enron.com': 9,
#  'veronica.espinoza@enron.com': inf,
#  'r..brackett@enron.com': inf,
#  's..bradford@enron.com': 7,
#  'r..conner@enron.com': inf,
#  'patrick.hanse@enron.com': 8,
#  'kelly.lovvorn@enron.com': inf,
#  'ann.murphy@enron.com': 13,
#  "schultz'.'kyle@enron.com": inf,
#  'kim.theriot@enron.com': 11,
#  'greg.wolfe@enron.com': 6,
#  'christian.yoder@enron.com': 19,
#  "origination'.'black@enron.com": inf,
#  "paul'.'choi@enron.com": inf,
#  "fairley'.'david@enron.com": inf,
#  'j..miller@enron.com': inf,
#  'steve.neal@enron.com': inf,
#  's..olinger@enron.com': 6,
#  'h..otto@enron.com': 9,
#  'david.parquet@enron.com': inf,
#  'beth.perlman@enron.com': inf,
#  'bo.petersen@enron.com': inf,
#  's..pollan@enron.com': 8,
#  'a..price@enron.com': inf,
#  'daniel.reck@enron.com': inf,
#  'leslie.reeves@enron.com': inf,
#  'brian.riley@enron.com': inf,
#  'suzy.robey@enron.com': inf,
#  'hpl.schneider@enron.com': inf,
#  "jim'.'schwieger@enron.com": inf,
#  'a..shankman@enron.com': 11,
#  'mary.smith@enron.com': 11,
#  'd..sorenson@enron.com': inf,
#  'p..south@enron.com': 6,
#  'a..allen@enron.com': inf,
#  'd..baughman@enron.com': 6,
#  "sally'.'beck@enron.com": inf,
#  'bob.bowen@enron.com': 9,
#  'craig.breslau@enron.com': 9,
#  "gary'.'bryan@enron.com": inf,
#  'cary.carrabine@enron.com': inf,
#  "larry'.'cash@enron.com": inf,
#  'brad.coleman@enron.com': inf,
#  "angie'.'collins@enron.com": inf,
#  'robert.cotten@enron.com': inf,
#  'james.ducote@enron.com': inf,
#  'michael.etringer@enron.com': 9,
#  'h..foster@enron.com': 6,
#  'sheila.glover@enron.com': inf,
#  "julie'.'gomez@enron.com": inf,
#  'lance.halgren@enron.com': inf,
#  "cortez'.'nicole@enron.com": inf,
#  "thomas'.'martin@enron.com": inf,
#  'stuart.staley@enron.com': inf,
#  'jung-suk.suh@enron.com': inf,
#  'mark.taylor@enron.com': 11,
#  'm..tholt@enron.com': 6,
#  'jake.thomas@enron.com': 9,
#  'janelle.scheuer@enron.com': 11,
#  'n..gilbert@enron.com': 9,
#  "lucci'.'paul@enron.com": inf,
#  "joseph'.'graham@enron.com": inf,
#  'lisa.mellencamp@enron.com': 11,
#  'tana.jones@enron.com': 19,
#  'shonnie.daniel@enron.com': 11,
#  'barbara.gray@enron.com': 12,
#  'steve.van@enron.com': inf,
#  "peggy'.'banczak@enron.com": inf,
#  'mary.cook@enron.com': 19,
#  'sandi.braband@enron.com': 19,
#  'elizabeth.white@enron.com': inf,
#  'carol.st@enron.com': inf,
#  'nathan.hlavaty@enron.com': inf,
#  'melissa.graves@enron.com': inf,
#  'susan.smith@enron.com': inf,
#  'l..taylor@enron.com': inf,
#  'p..reinhardt@enron.com': inf,
#  "adam'.'gross@enron.com": inf,
#  'h..lewis@enron.com': 6,
#  "lucy'.'ortiz@enron.com": inf,
#  'barend.vanderhorst@enron.com': inf,
#  'james.barker@enron.com': inf,
#  "driscoll'.'marde@enron.com": inf,
#  "timothy'.'ray@enron.com": inf,
#  "monica'.'roberts@enron.com": inf,
#  "james'.'shirley@enron.com": inf,
#  'stacy.dickson@enron.com': 19,
#  'linda.ewing@enron.com': inf,
#  "john'.'grass@enron.com": inf,
#  'joanie.ngo@enron.com': inf,
#  'r..lilly@enron.com': inf,
#  "lisa'.'csikos@enron.com": inf,
#  'j..hanson@enron.com': 9,
#  'katherine.herrera@enron.com': inf,
#  'kevin.bosse@enron.com': 9,
#  'william.stuart@enron.com': inf,
#  'isabel.resendez@enron.com': 10,
#  'drew.hill@enron.com': 10,
#  'sheetal.patel@enron.com': 10,
#  "martin.o'leary@enron.com": inf,
#  'souad.mahmassani@enron.com': 7,
#  'john.singer@enron.com': inf,
#  'jay.knoblauh@enron.com': inf,
#  "ned'.'higgins@enron.com": inf,
#  'dan.mccairns@enron.com': inf,
#  'andrew.greer@enron.com': 44,
#  "george'.'hope@enron.com": inf,
#  "daniel'.'diamond@enron.com": inf,
#  "teresa'.'mandola@enron.com": inf,
#  'andrea.hauser@enron.com': inf,
#  "justin'.'rostant@enron.com": inf,
#  'lisa.gillette@enron.com': 10,
#  "harry'.'bucalo@enron.com": inf,
#  "bryan'.'hull@enron.com": inf,
#  "bill'.'kyle@enron.com": inf,
#  'gerald.lofton@enron.com': inf,
#  "marshall'.'cheryl@enron.com": inf,
#  'jack.simunek@enron.com': inf,
#  'candy.bywaters@enron.com': inf,
#  'kenneth.kaase@enron.com': inf,
#  'ron.green@enron.com': inf,
#  'jennifer.blay@enron.com': inf,
#  'audrey.cook@enron.com': 14,
#  'teresa.seibel@enron.com': inf,
#  'dennis.benevides@enron.com': inf,
#  'tracy.ngo@enron.com': inf,
#  'joanne.harris@enron.com': inf,
#  "'rmservices'@enron.com": inf,
#  "timothy'.'hamilton@enron.com": inf,
#  'todd.lambert@enron.com': inf,
#  "morgan'.'babin@enron.com": inf,
#  'paul.tate@enron.com': 10,
#  'laura.arnold@enron.com': inf,
#  'jay.blaine@enron.com': 44,
#  'zarin.imam@enron.com': inf,
#  'alain.diza@enron.com': 10,
#  "sharon'.'hausinger@enron.com": inf,
#  "jeff'.'coates@enron.com": inf,
#  'christina.bangle@enron.com': inf,
#  'rhonda.smith@enron.com': 10,
#  'amanda.boettcher@enron.com': inf,
#  'tom.moran@enron.com': 11,
#  'sherry.pendegraft@enron.com': 10,
#  'lisa.valderrama@enron.com': 11,
#  'tim.weithman@enron.com': inf,
#  'kyle.griffin@enron.com': inf,
#  'lester.rawson@enron.com': 14,
#  'm.hall@enron.com': 9,
#  "kathryn'.'bussell@enron.com": inf,
#  'bryce.baxter@enron.com': 9,
#  'bernard.dahanayake@enron.com': inf,
#  'richard.deming@enron.com': inf,
#  'janie.aguayo@enron.com': inf,
#  'derek.bailey@enron.com': 9,
#  'diane.anderson@enron.com': 9,
#  'joe.hunter@enron.com': 9,
#  'ellen.wallumrod@enron.com': 9,
#  'lisa.lees@enron.com': 9,
#  'stephanie.sever@enron.com': 9,
#  'daniel.salinas@enron.com': 10,
#  'josephine.logan@enron.com': inf,
#  'joni.fisher@enron.com': inf,
#  'meredith.eggleston@enron.com': inf,
#  'vladimir.gorny@enron.com': 10,
#  'cindy.vachuska@enron.com': inf,
#  'angelo.miroballi@enron.com': inf,
#  'jess.hewitt@enron.com': inf,
#  'melissa.ratnala@enron.com': inf,
#  'w..vickers@enron.com': 9,
#  'rumaldo.lopez@enron.com': inf,
#  'marc.de@enron.com': inf,
#  'debra.young@enron.com': inf,
#  'jeff.arnold@enron.com': inf,
#  'ann.johnson@enron.com': inf,
#  'ruthann.frausto@enron.com': inf,
#  'mark.koenig@enron.com': 11,
#  'robert.geheb@enron.com': inf,
#  'santiago.garcia@enron.com': 10,
#  'vineet.arora@enron.com': inf,
#  'jan.sutherland@enron.com': 10,
#  'josh.mayes@enron.com': inf,
#  'geraldine.irvine@enron.com': 10,
#  'rebecca.ford@enron.com': inf,
#  'j..brewer@enron.com': inf,
#  'suzanne.christiansen@enron.com': 9,
#  'yolanda.cordova-gilbert@enron.com': inf,
#  'charles.weldon@enron.com': 6,
#  'jason.wolfe@enron.com': 11,
#  'robert.virnau@enron.com': inf,
#  'tyrone.brown@enron.com': inf,
#  'amy.villasenor@enron.com': inf,
#  'larry.fenstad@enron.com': inf,
#  'lynne.dix@enron.com': inf,
#  'morris.brassfield@enron.com': 19,
#  'shelly.mendel@enron.com': 9,
#  'ted.evans@enron.com': inf,
#  'bill.berkeland@enron.com': inf,
#  'dina.snow@enron.com': 10,
#  'a..ryan@enron.com': inf,
#  'lynn.johnson@enron.com': inf,
#  'kurt.lindahl@enron.com': inf,
#  'thane.twiggs@enron.com': inf,
#  'mike.thomas@enron.com': inf,
#  'randal.maffett@enron.com': 24,
#  'm..grace@enron.com': inf,
#  'ruth.concannon@enron.com': 8,
#  'daniel.lisk@enron.com': 10,
#  'mark.adleman@enron.com': inf,
#  'tushar.dhruv@enron.com': inf,
#  'sandy.olitsky@enron.com': inf,
#  'rinetia.turner@enron.com': inf,
#  'lance.schuler@enron.com': inf,
#  'kathie.grabstald@enron.com': inf,
#  'mark.breese@enron.com': 10,
#  'a..terlip@enron.com': inf,
#  'hillary.mack@enron.com': inf,
#  'phil.demoes@enron.com': 12,
#  'steven.curlee@enron.com': inf,
#  'ann.matson@enron.com': inf,
#  'gil.muhl@enron.com': 9,
#  'nelson.ferries@enron.com': 9,
#  'nick.moshou@enron.com': inf,
#  'shawn.franks@enron.com': inf,
#  'david.jones@enron.com': 10,
#  'eric.thode@enron.com': inf,
#  'clint.shay@enron.com': inf,
#  'darrin.morris@enron.com': inf,
#  'mark.jordan@enron.com': inf,
#  'pete.releford@enron.com': inf,
#  'robin.chavez@enron.com': inf,
#  'joel.valdez@enron.com': inf,
#  'khalid.makiya@enron.com': inf,
#  'mark.garrett@enron.com': inf,
#  'nathan.childs@enron.com': inf,
#  'sheyi.joseph@enron.com': inf,
#  'tavares.johnson@enron.com': inf,
#  'brandon.parker@enron.com': inf,
#  'jaime.gonzales@enron.com': inf,
#  'steve.herron@enron.com': inf,
#  'dolph.selten@enron.com': inf,
#  'julie.clyatt@enron.com': 9,
#  'darren.adamik@enron.com': 9,
#  'p..adams@enron.com': 9,
#  'habib.ahsan@enron.com': 9,
#  'd.alexander@enron.com': 9,
#  'diana.allen@enron.com': 9,
#  'jason.althaus@enron.com': 9,
#  'susan.amador@enron.com': 9,
#  'amanullah.aman@enron.com': 9,
#  'sherry.anastas@enron.com': 9,
#  'dan.arellano@enron.com': 9,
#  'ravi.arumbakkam@enron.com': 9,
#  'chris.austin@enron.com': 9,
#  'luis.aybar@enron.com': 9,
#  'natalie.baker@enron.com': 9,
#  'arun.balasundaram@enron.com': 9,
#  'ted.ballinger@enron.com': 9,
#  'charles.ballmer@enron.com': 9,
#  'michael.barber@enron.com': 9,
#  'eric.bass@enron.com': 6,
#  'nilay.basu@enron.com': 9,
#  'chris.behney@enron.com': 9,
#  'cedric.belt@enron.com': 9,
#  'troy.beyer@enron.com': 9,
#  'randy.bhatia@enron.com': 9,
#  'jae.black@enron.com': 9,
#  'gary.bode@enron.com': 9,
#  'ryan.brennan@enron.com': 9,
#  'karen.buckley@enron.com': 9,
#  'victor.bulbes@enron.com': 9,
#  'simon.burgess@enron.com': 9,
#  'janine.cashin@enron.com': 9,
#  'michael.castillo@enron.com': 9,
#  'john.cheng@enron.com': 9,
#  'diana.cioffi@enron.com': 9,
#  'kristen.clause@enron.com': 8,
#  'frank.coles@enron.com': 9,
#  'paige.cox@enron.com': 9,
#  'a..cummings@enron.com': 9,
#  'amanda.curless@enron.com': 9,
#  'neil.davies@enron.com': 9,
#  'roberto.deleon@enron.com': 9,
#  'janet.devereaux@enron.com': 9,
#  'dan.dietrich@enron.com': 9,
#  'michael.dolan@enron.com': 9,
#  'keith.dziadek@enron.com': 9,
#  'clay.elliott@enron.com': 9,
#  'frank.ermis@enron.com': 5,
#  'j..ewing@enron.com': 9,
#  'amy.fitzpatrick@enron.com': 9,
#  'bryant.frihart@enron.com': 8,
#  'l..gay@enron.com': 5,
#  'doug.gichana@enron.com': 9,
#  'c..giron@enron.com': 8,
#  'c..gossett@enron.com': 9,
#  'marlin.gubser@enron.com': 9,
#  'claudia.guerra@enron.com': 9,
#  'joe.hall@enron.com': 9,
#  'mark.hall@enron.com': 9,
#  'd..hogan@enron.com': 9,
#  'james.hungerford@enron.com': 7,
#  'charles.jacobs@enron.com': 9,
#  'matthew.james@enron.com': 9,
#  'tammy.jaquet@enron.com': 9,
#  'anthony.jarrett@enron.com': 9,
#  'james.johnston@enron.com': 11,
#  'brad.jones@enron.com': 9,
#  'monte.jones@enron.com': 9,
#  'shivshankar.kandavelu@enron.com': 9,
#  'bill.knox@enron.com': 9,
#  'brian.larkin@enron.com': 9,
#  'rick.le@enron.com': 9,
#  'kathy.link@enron.com': 9,
#  'kori.loibl@enron.com': 9,
#  'm..love@enron.com': 7,
#  'danielle.marcinkowski@enron.com': 9,
#  'bob.mcauliffe@enron.com': 9,
#  'errol.mclaughlin@enron.com': 9,
#  'darren.mcnair@enron.com': 9,
#  'jason.mcnair@enron.com': 9,
#  'genaro.mendoza@enron.com': 9,
#  'bruce.mills@enron.com': 8,
#  'l..mims@enron.com': 6,
#  'g..moore@enron.com': 9,
#  'daniel.muschar@enron.com': 9,
#  'donnie.myers@enron.com': 9,
#  'acey.nash@enron.com': 9,
#  'john.oh@enron.com': 9,
#  'matthew.olney@enron.com': 9,
#  'michael.olsen@enron.com': 5,
#  'kari.oquinn@enron.com': 9,
#  "ryan.o'rourke@enron.com": 9,
#  'david.oxley@enron.com': 8,
#  'scott.palmer@enron.com': 7,
#  'stephen.perich@enron.com': 9,
#  'richard.pinion@enron.com': 9,
#  'faheem.qavi@enron.com': 9,
#  'dutch.quigley@enron.com': 5,
#  'edward.ray@enron.com': 9,
#  'trey.rhodes@enron.com': 9,
#  'jenny.rub@enron.com': 9,
#  'scott.shishido@enron.com': 9,
#  'steve.shortt@enron.com': 9,
#  'john.shupak@enron.com': 9,
#  'jeanie.slone@enron.com': 9,
#  'bruce.smith@enron.com': 9,
#  'mathew.smith@enron.com': 9,
#  'cathy.sprowls@enron.com': 9,
#  'micah.staggs@enron.com': 9,
#  'david.steiner@enron.com': 9,
#  'patti.sullivan@enron.com': 9,
#  'joseph.taylor@enron.com': 9,
#  'todd.thelen@enron.com': 9,
#  'benjamin.thompson@enron.com': 9,
#  'brent.tiner@enron.com': 9,
#  'barry.tycholiz@enron.com': 7,
#  'carlos.uribe@enron.com': 9,
#  'john.valdes@enron.com': 9,
#  'leah.van@enron.com': 9,
#  'laura.vargas@enron.com': 9,
#  'frank.vickers@enron.com': 6,
#  'melissa.videtto@enron.com': 7,
#  'laura.vuittonet@enron.com': 6,
#  'enron.announcement@enron.com': inf,
#  'enron.chairman@enron.com': inf,
#  'henry.safety@enron.com': inf,
#  'general.announcement@enron.com': inf,
#  'victor.lamadrid@enron.com': 8,
#  'l..kelly@enron.com': 8,
#  'jeff.royed@enron.com': 7,
#  'michael.yowman@enron.com': inf,
#  'eSource@ENRON': inf,
#  'announcements.enron@enron.com': inf,
#  'dl-ga-all_domestic@enron.com': inf,
#  'dawn.mcdonald@enron.com': 11,
#  'steve.wang@enron.com': 4,
#  'traders.dl-netco@enron.com': 8,
#  'traders.eol@enron.com': 17,
#  'brawner@enron.com': inf,
#  'feedback@intcx.com': inf,
#  'iceuserslist@list.intcx.com': inf,
#  'robert.allwein@enron.com': 8,
#  'shanna.boudreaux@enron.com': 8,
#  'tamara.carter@enron.com': 8,
#  'joann.collins@enron.com': 8,
#  'stephanie.erwin@enron.com': 10,
#  'clarissa.garcia@enron.com': 8,
#  'steve.gillespie@enron.com': 8,
#  'lia.halstead@enron.com': 8,
#  'meredith.homco@enron.com': 8,
#  'kelly.loocke@enron.com': 8,
#  'scott.loving@enron.com': 15,
#  'chris.ordway@enron.com': 8,
#  'michael.pritchard@enron.com': 10,
#  'dan.prudenti@enron.com': 8,
#  'robert.ramirez@enron.com': 8,
#  'christina.sanchez@enron.com': 8,
#  'tracy.wood@enron.com': 8,
#  'l..driscoll-ernest@enron.com': 10,
#  'robert.superty@enron.com': 8,
#  's..theriot@enron.com': 9,
#  'c..aucoin@enron.com': 10,
#  'jungsuk.suh@enron.com': inf,
#  'leonidas.savvas@enron.com': 8,
#  'alejandra.chavez@enron.com': 8,
#  'darren.espey@enron.com': 8,
#  'kulvinder.fowler@enron.com': 7,
#  'luchas.johnson@enron.com': 7,
#  'hal.mckinney@enron.com': 7,
#  'ashley.worthing@enron.com': 7,
#  'suzanne.calcagno@enron.com': 4,
#  'dl-ga-all_domestic2@enron.com': inf,
#  'cocob@pdq.net': 11,
#  'dl-ga-all_enron_worldwide1@enron.com': inf,
#  'jr..legal@enron.com': inf,
#  'dl-ga-all_enron_worldwide3@enron.com': inf,
#  'alex.saldana@enron.com': 8,
#  'brandee.jackson@enron.com': 8,
#  'heather.choate@enron.com': 8,
#  'jesse.villarreal@enron.com': 8,
#  'dl-ga-all_netco@enron.com': inf,
#  'coo.jeff@enron.com': inf,
#  'j..legler@enron.com': 7,
#  'a..gomez@enron.com': 6,
#  'brian.redmond@enron.com': 6,
#  'gary.bryan@enron.com': 6,
#  'jd.buss@enron.com': 6,
#  'j..farmer@enron.com': 7,
#  'bryan.hull@enron.com': 8,
#  'joe.parks@enron.com': 6,
#  'chance.rabon@enron.com': 6,
#  'patrick.ryder@enron.com': 6,
#  'd..winfree@enron.com': 6,
#  'sbrawne@ect.enron.com': 17,
#  'shauywn.smith@enron.com': 10,
#  'jim.willis@enron.com': 15,
#  't..zivley@enron.com': 15,
#  'lindsay.culotta@enron.com': 8,
#  'e.murrell@enron.com': 8,
#  'patrick.tucker@enron.com': 8,
#  'gary.taylor@enron.com': 9,
#  'chris.walker@enron.com': 9,
#  'virawan.yawapongsiri@enron.com': 9,
#  'joan.collins@enron.com': 6,
#  'a..roberts@enron.com': 6,
#  'jose.marquez@enron.com': 6,
#  'kennedy.kathleen@enron.com': 17,
#  'newland.kody@enron.com': 18,
#  'caldwell.sue@enron.com': 19,
#  'schnitzer.susan@enron.com': 19,
#  'chairman.ken@enron.com': inf,
#  'dl-ga-all_enron_worldwide@enron.com': inf,
#  'rachel.bryant@enron.com': 10,
#  'bart.burk@enron.com': 9,
#  'kathryn.bussell@enron.com': 10,
#  'tetteh.canacoo@enron.com': 10,
#  'catalina.cardenas@enron.com': 10,
#  'brandon.cavazos@enron.com': 10,
#  'amy.cavazos@enron.com': 9,
#  'bonnie.chang@enron.com': 9,
#  'sheila.chang@enron.com': 10,
#  'elena.chilkina@enron.com': 10,
#  'lindon.chiu@enron.com': 10,
#  'shawn.chmil@enron.com': 10,
#  'andrea.clements@enron.com': 10,
#  'venita.coleman@enron.com': 10,
#  'angie.collins@enron.com': 10,
#  'wes.colwell@enron.com': 9,
#  'karla.compean@enron.com': 10,
#  'chris.cramer@enron.com': 10,
#  'jason.panos@enron.com': 10,
#  'troy.denetsosie@enron.com': 10,
#  'joseph.des@enron.com': 10,
#  'l..dinari@enron.com': 10,
#  'jad.doan@enron.com': 10,
#  'david.dronet@enron.com': 10,
#  'lisa.druzbik@enron.com': 10,
#  'gwen.espree@enron.com': 10,
#  'brian.falik@enron.com': 10,
#  'chris.figueroa@enron.com': 10,
#  'loftus.fitzwater@enron.com': 10,
#  'b..fleming@enron.com': 10,
#  'h..fletcher@enron.com': 10,
#  'neithard.foley@enron.com': 10,
#  'keith.fraley@enron.com': 10,
#  'carole.frank@enron.com': 10,
#  'scott.franklin@enron.com': 10,
#  'theresa.franklin@enron.com': 10,
#  'cynthia.franklin@enron.com': 10,
#  'ben.freeman@enron.com': 10,
#  'amy.freeman@enron.com': 10,
#  'shalesh.ganjoo@enron.com': 10,
#  'maria.garza@enron.com': 9,
#  'jeff.gerl@enron.com': 10,
#  'tammy.gilmore@enron.com': 10,
#  'alexia.gonzales@enron.com': 10,
#  'e.grannen@enron.com': 10,
#  'george.grant@enron.com': 10,
#  'shane.green@enron.com': 10,
#  'paul.gregory@enron.com': 10,
#  'donna.greif@enron.com': 10,
#  'shannon.groenewold@enron.com': 9,
#  'l..hall@enron.com': 10,
#  'mason.hamlin@enron.com': 10,
#  'kimberly.hardy@enron.com': 10,
#  'darian.hawkins@enron.com': 10,
#  'craig.hawkins@enron.com': 10,
#  'helen.haynes@enron.com': 10,
#  'daniel.haynes@enron.com': 10,
#  'tamika.hebert@enron.com': 10,
#  'a.hernandez@enron.com': 10,
#  'l..hernandez@enron.com': 10,
#  'fernando.herrera@enron.com': 10,
#  'lisa.hesse@enron.com': 10,
#  'p..hewitt@enron.com': 10,
#  'wendy.hiatt@enron.com': 10,
#  'nick.hiemstra@enron.com': 10,
#  'ned.higgins@enron.com': 10,
#  'chris.hilgert@enron.com': 10,
#  'ryan.hinze@enron.com': 10,
#  'stephanie.hopkins@enron.com': 7,
#  'jonathan.horne@enron.com': 10,
#  'sarah.hotze@enron.com': 10,
#  'peter.hoyt@enron.com': 10,
#  'george.huan@enron.com': 10,
#  'jason.huang@enron.com': 10,
#  'clinton.hurt@enron.com': 10,
#  'monica.hwang@enron.com': 10,
#  'chris.hyde@enron.com': 10,
#  'angela.hylton@enron.com': 10,
#  'jennifer.jennings@enron.com': 10,
#  'exec.jones@enron.com': 10,
#  'melissa.jones@enron.com': 10,
#  'dayem.khandker@enron.com': 9,
#  'lisa.kinsey@enron.com': 8,
#  'mark.knippa@enron.com': 9,
#  'sladana-anna.kulic@enron.com': 10,
#  'milen.kurdov@enron.com': 10,
#  'tori.kuykendall@enron.com': 6,
#  'kirk.lenart@enron.com': 10,
#  'barry.lewis@enron.com': 10,
#  'jozef.lieskovsky@enron.com': 9,
#  'kelli.little@enron.com': 6,
#  'jeremy.lo@enron.com': 10,
#  'laura.luce@enron.com': 8,
#  'christie.manck@enron.com': 10,
#  'jabari.martin@enron.com': 10,
#  'martin.thomas@enron.com': 10,
#  'jennifer.martinez@enron.com': 10,
#  'robert.mattice@enron.com': 10,
#  'michael.mccaskin@enron.com': 10,
#  'lisa.mcclendon@enron.com': 10,
#  'chris.meyer@enron.com': 10,
#  'jim.meyn@enron.com': 9,
#  'david.michels@enron.com': 10,
#  'andrew.migliano@enron.com': 10,
#  'andrew.miles@enron.com': 10,
#  'kevin.miller@enron.com': 10,
#  'jana.mills@enron.com': 10,
#  'jeffrey.molinaro@enron.com': 10,
#  'john.morris@enron.com': 10,
#  't..muzzy@enron.com': 10,
#  'junellen.neese@enron.com': 10,
#  'michelle.nelson@enron.com': 10,
#  'lisbet.newton@enron.com': 10,
#  'thinh.nguyen@enron.com': 10,
#  "justin.o'malley@enron.com": 8,
#  'jennie.pai@enron.com': 10,
#  'neeran.pathak@enron.com': 10,
#  'biliana.pehlivanova@enron.com': 9,
#  'cora.pendergrass@enron.com': 9,
#  'christopher.pernoud@enron.com': 10,
#  'denver.plachy@enron.com': 7,
#  'stephen.plauche@enron.com': 7,
#  'phil.polsky@enron.com': 10,
#  'jessica.presas@enron.com': 10,
#  'daniel.quezada@enron.com': 10,
#  'eva.rainer@enron.com': 10,
#  'david.ratliff@enron.com': 10,
#  'pauline.reyes@enron.com': 10,
#  'sean.riordan@enron.com': 10,
#  'chaun.roberts@enron.com': 10,
#  'linda.roberts@enron.com': 8,
#  'ruby.robinson@enron.com': 10,
#  'araceli.romero@enron.com': 10,
#  'justin.rostant@enron.com': 10,
#  'michael.salinas@enron.com': 10,
#  'lauren.schlesinger@enron.com': 10,
#  'm..scott@enron.com': 10,
#  'rahul.seksaria@enron.com': 10,
#  'user.shah@enron.com': 10,
#  'r..shepperd@enron.com': 9,
#  'kristann.shireman@enron.com': 10,
#  'digna.showers@enron.com': 10,
#  'critz.smith@enron.com': 10,
#  'f..smith@enron.com': 9,
#  'mark.smith@enron.com': 10,
#  'joseph.smith@enron.com': 10,
#  'william.smith@enron.com': 10,
#  'melissa.solis@enron.com': 10,
#  'elizabeth.soto@enron.com': 10,
#  'gulay.soykok@enron.com': 10,
#  'walter.spiegelhauer@enron.com': 10,
#  'stephanie.stehling@enron.com': 10,
#  ...}
