# %%
from utils.graph import Grafo
from heapq import heapify, heappop, heappush

# %%
grafo = Grafo.load_pickled_graph("../graph/graph.pkl")

# %%
def djisktra(grafo: Grafo, initial_node) -> dict:
    distances = distances = {node: float("inf") for node in grafo.adj_list}
    distances[initial_node] = 0

    # inicio priority queue
    pq = [(0, initial_node)]
    heapify(pq)

    visited = set()

    while pq:
        current_distance, current_node = heappop(
            pq
        )  # pega o no com a menor distancia
        if current_node in visited:
            continue
        visited.add(current_node)

        for neighbor, weight in grafo.adj_list[current_node]:
            # Calcula distancia do no atual ate o vizinho
            tentative_distance = current_distance + weight
            if tentative_distance < distances[neighbor]:
                #se achar distancia menor que atual coloca na lista de distancias
                distances[neighbor] = tentative_distance
                heappush(pq, (tentative_distance, neighbor))

    return distances

# %%
distancias = djisktra(grafo, 'jons@amerexenergy.com')
distancias
# Out:
# {'jons@amerexenergy.com': 0,
#  'sandra.f.brawner@enron.com': 1,
#  'enron.announcements@enron.com': inf,
#  'all.houston@enron.com': inf,
#  'sandra.brawner@enron.com': 4,
#  'kennethbrawner@msn.com': 2,
#  'perfmgmt@enron.com': inf,
#  'jared.kaiser@enron.com': 3,
#  'kam.keiser@enron.com': 3,
#  'scott.neal@enron.com': 2,
#  'michael.garberding@enron.com': 8,
#  'cris.sherman@enron.com': 4,
#  'morris.clark@enron.com': 9,
#  'teresa.bushman@enron.com': 8,
#  'william.bradford@enron.com': 9,
#  'ragan.bond@enron.com': 4,
#  'outlook.team@enron.com': 5,
#  'ann.vaughn@enron.com': 6,
#  'wilson.barbee@enron.com': 6,
#  'estalee.russi@enron.com': 6,
#  'felicia.beal@enron.com': 6,
#  'fran.fagan@enron.com': 4,
#  'gary.smith@enron.com': 6,
#  'jerry.harkreader@enron.com': 6,
#  'john.anderson@enron.com': 4,
#  'jorge.olivares@enron.com': 6,
#  'kristin.passmore@enron.com': 6,
#  'leesa.hutcherson@enron.com': 6,
#  'michele.denby@enron.com': 6,
#  'miranda.southard@enron.com': 6,
#  'renee.pena@enron.com': 6,
#  'rita.houston@enron.com': 6,
#  'roger.sumlin@enron.com': 6,
#  'wilford.dodd@enron.com': 6,
#  'william.keeney@enron.com': 6,
#  'brad.alford@enron.com': 6,
#  'bruce.golden@enron.com': 6,
#  'bryan.williams@enron.com': 6,
#  'carl.tricoli@enron.com': 4,
#  'christopher.coffman@enron.com': 6,
#  'chu.wang@enron.com': 6,
#  'charles.ward@enron.com': 6,
#  'w.duran@enron.com': 6,
#  'david.marks@enron.com': 4,
#  'eric.rhodes@enron.com': 6,
#  'farouk.lalji@enron.com': 6,
#  'george.schaefer@enron.com': 6,
#  'greg.blair@enron.com': 6,
#  'greg.martin@enron.com': 4,
#  'jeff.hoover@enron.com': 6,
#  'john.moore@enron.com': 6,
#  'lisa.zarsky@enron.com': 4,
#  'mario.alonso@enron.com': 6,
#  'michael.miller@enron.com': 6,
#  'mitch.robinson@enron.com': 4,
#  'naveed.ahmed@enron.com': 5,
#  'paulita.olvera@enron.com': 6,
#  'tina.holcombe@enron.com': 4,
#  'tina.rode@enron.com': 3,
#  'tosha.henderson@enron.com': 6,
#  'andrea.ring@enron.com': 3,
#  'brad.mckay@enron.com': 3,
#  'chris.germany@enron.com': 3,
#  'judy.townsend@enron.com': 3,
#  'kimberly.bates@enron.com': 4,
#  'peter.keavey@enron.com': 4,
#  'scott.goodell@enron.com': 3,
#  'sean.boyle@enron.com': 5,
#  'susan.pereira@enron.com': 4,
#  'victoria.versen@enron.com': 3,
#  'vladi.pimenov@enron.com': 3,
#  'derek.anderson@enron.com': 6,
#  'susan.huston@enron.com': 6,
#  'burak.hurbas@enron.com': 6,
#  'colin.crowley@enron.com': 6,
#  'lisa.rizzo@enron.com': 6,
#  'richard.johnson@enron.com': 6,
#  'sandra.torres@enron.com': 6,
#  'angela.stie@enron.com': 6,
#  'armando.lira@enron.com': 6,
#  "audry.o'toole@enron.com": 6,
#  'beverly.filer@enron.com': 6,
#  'helen.jeschke@enron.com': 6,
#  'john.harrison@enron.com': 6,
#  'kristi.louthan@enron.com': 6,
#  'michael.philips@enron.com': 6,
#  'peggy.rathmell@enron.com': 6,
#  'robert.jr@enron.com': 6,
#  'shannon.cobb@enron.com': 6,
#  'sharon.stringfellow@enron.com': 6,
#  'valarie.curry@enron.com': 6,
#  'pama9@flash.net': 3,
#  'brian.hoskins@enron.com': 5,
#  's.schnitzer@worldnet.att.net': 2,
#  'kennethbrawner@email.msn.com': 5,
#  'jeffrey.shankman@enron.com': 5,
#  'all.worldwide@enron.com': inf,
#  'jesus.guerra@enron.com': 4,
#  'parking.transportation@enron.com': 5,
#  'jons@amerexyenergy.com': 5,
#  'airam.arteaga@enron.com': 4,
#  'robin.barbe@enron.com': 4,
#  'john.taylor@enron.com': 3,
#  'dick.jenkins@enron.com': 4,
#  'scott.hendrickson@enron.com': 3,
#  'dan.junek@enron.com': 4,
#  'tammi.depaolis@enron.com': 4,
#  'rrussin@natsource.com': 5,
#  'kimberly.brown@enron.com': 5,
#  'ina.rangel@enron.com': 3,
#  'colleen.sullivan@enron.com': 4,
#  'phillip.allen@enron.com': 4,
#  'thomas.martin@enron.com': 4,
#  'greg.mcclendon@enron.com': 4,
#  'kimberly.olinger@enron.com': 5,
#  'hunter.shively@enron.com': 4,
#  'elsa.villarreal@enron.com': 4,
#  'keith.holst@enron.com': 3,
#  'kate.fraser@enron.com': 4,
#  'andrew.lewis@enron.com': 4,
#  'john.lavorato@enron.com': 2,
#  'mike.grigsby@enron.com': 3,
#  'martin.cuilla@enron.com': 3,
#  'deirdre.mccaffrey@enron.com': 4,
#  'sylvia.pollan@enron.com': 4,
#  'geoff.storey@enron.com': 3,
#  'louis.dicarlo@enron.com': 4,
#  'ksmalek@aep.com': 4,
#  'tk.lohman@enron.com': 2,
#  'john.griffith@enron.com': 3,
#  'russ.severson@enron.com': 3,
#  'scott.mills@enron.com': 4,
#  'jeffrey.gossett@enron.com': 4,
#  'david.delainey@enron.com': 5,
#  'louise.kitchen@enron.com': 2,
#  'stouchstone@natsource.com': 3,
#  'matthew.fleming@enron.com': 5,
#  'waltonw@epenergy.com': 5,
#  'tricia.spence@enron.com': 5,
#  'kennethbrawner@mns.com': 5,
#  'jons@amerexenergy': 5,
#  'jons@amerex.com': 2,
#  'byoung@prebon.com': 5,
#  'public.relations@enron.com': inf,
#  'eligible.employees@enron.com': inf,
#  'sschnitz@jcpenney.com': 1,
#  'paulla@maritz.com': 1,
#  'robert.k.rodriguez@db.com': 1,
#  'lmorris1@pclient.ml.com': 1,
#  'gee_ruiz@hotmail.com': 1,
#  'ddunnavant@reliantenergy.com': 1,
#  'aertel@evomarkets.com': 1,
#  'jrschnitzer@hotmail.com': 1,
#  'prebonenergy@corporateecards.com': inf,
#  'sarah.mulholland@enron.com': 4,
#  'maureen.smith@enron.com': 4,
#  'tom.donohoe@enron.com': 2,
#  'kelli.stevens@enron.com': 3,
#  'jason.williams@enron.com': 4,
#  'patrice.mims@enron.com': 4,
#  'kevin.ruscitti@enron.com': 3,
#  'jay.reitmeyer@enron.com': 3,
#  'kenneth.shulklapper@enron.com': 4,
#  'matthew.lenhart@enron.com': 3,
#  'steven.south@enron.com': 4,
#  'jane.tholt@enron.com': 4,
#  'monique.sanchez@enron.com': 3,
#  'carey.metz@enron.com': 4,
#  'stacey.neuweiler@enron.com': 4,
#  'liz.bellamy@enron.com': 4,
#  'jim.schwieger@enron.com': 2,
#  'daren.farmer@enron.com': 4,
#  'lauri.allen@enron.com': 4,
#  'edward.gottlob@enron.com': 4,
#  'gary.lamphier@enron.com': 4,
#  'danny.conner@enron.com': 4,
#  'john.arnold@enron.com': 2,
#  'mike.maggi@enron.com': 2,
#  'larry.may@enron.com': 3,
#  'mfortuna@tfsbrokers.com': 5,
#  'jennifer.fraser@enron.com': 4,
#  'jennifer.shipos@enron.com': 3,
#  'russell.diamond@enron.com': 4,
#  'kenny.soignet@enron.com': inf,
#  'berney.aucoin@enron.com': inf,
#  'janet.dietrich@enron.com': 5,
#  'julie.gomez@enron.com': inf,
#  'joseph.hrgovcic@enron.com': inf,
#  'calvin.johnson@enron.com': inf,
#  'heather.kendall@enron.com': inf,
#  'jean.mrha@enron.com': 3,
#  'chris.foster@enron.com': inf,
#  'fred.lagrasta@enron.com': 3,
#  'michael.cowan@enron.com': 3,
#  'chris.connelly@enron.com': inf,
#  'daniel.diamond@enron.com': 2,
#  'per.sekse@enron.com': inf,
#  'lee.papayoti@enron.com': inf,
#  'liz.taylor@enron.com': 4,
#  'marc.horowitz@enron.com': inf,
#  'sunil.dalal@enron.com': inf,
#  'clayton.vernon@enron.com': 4,
#  'frank.hayden@enron.com': 4,
#  'kimberly.hillis@enron.com': 3,
#  'elsa.piekielniak@enron.com': inf,
#  'sachin.gandhi@enron.com': inf,
#  'paul.lucci@enron.com': inf,
#  'caroline.abramo@enron.com': inf,
#  'russell.dyk@enron.com': inf,
#  'paul.bieniawski@enron.com': 5,
#  'gregory.schockling@enron.com': inf,
#  'mog.heu@enron.com': 4,
#  'enron.states@enron.com': inf,
#  'lucy.marshall@enron.com': 5,
#  'lesli.campbell@enron.com': 5,
#  'afinch@natsource.com': 5,
#  'melba.lozano@enron.com': 4,
#  'clement.abrams@enron.com': 7,
#  'donna.lowry@enron.com': 9,
#  'jeffrey.hodge@enron.com': 8,
#  'joseph.deffner@enron.com': 6,
#  'molly.harris@enron.com': 9,
#  'pushkar.shahi@enron.com': 9,
#  'sara.shackleton@enron.com': 8,
#  'brent.spiller@enron.com': 5,
#  'clare.santana@gte.net': 5,
#  'mathew.gimble@enron.com': inf,
#  'david.fairley@enron.com': 5,
#  'ozzie.pagan@enron.com': 4,
#  'rusty.stevens@enron.com': inf,
#  'gautam.gupta@enron.com': 3,
#  'stephanie.miller@enron.com': 3,
#  'john.hodge@enron.com': 3,
#  'ed.mcmichael@enron.com': 4,
#  'herman.manis@enron.com': inf,
#  'sheila.tweed@enron.com': 7,
#  'barton.clark@enron.com': 8,
#  'mike.coleman@enron.com': inf,
#  'michael.nanny@enron.com': inf,
#  'richard.bickings@enron.com': inf,
#  'walter.coffer@enron.com': inf,
#  'lisa.bills@enron.com': 8,
#  'kay.mann@enron.com': 7,
#  'patrick.maloy@enron.com': inf,
#  'ted.ryan@enron.com': inf,
#  'dave.kellermeyer@enron.com': inf,
#  'george.mccormick@enron.com': 7,
#  'webb.jennings@enron.com': inf,
#  'karen.carter@enron.com': inf,
#  'kevin.presto@enron.com': 3,
#  'rogers.herndon@enron.com': 2,
#  'office.chairman@enron.com': inf,
#  'kimat.singla@enron.com': 3,
#  'enron.mail@enron.com': inf,
#  'megan.angelos@enron.com': 5,
#  'all.employees@enron.com': inf,
#  'houston.report@enron.com': inf,
#  'lcjo@dynegy.com': 1,
#  'adam.johnson@enron.com': 4,
#  'jennifer.denny@enron.com': 4,
#  'david.forster@enron.com': 3,
#  'torrey.moorer@enron.com': 4,
#  'matt.motsinger@enron.com': 4,
#  'savita.puthigai@enron.com': 5,
#  'jennifer.rosado@enron.com': 4,
#  'tammie.schoppe@enron.com': 3,
#  'craig.taylor@enron.com': 3,
#  'andy.zipper@enron.com': 3,
#  'bharat.khanna@enron.com': inf,
#  'mike.roberts@enron.com': inf,
#  'chris.gaskill@enron.com': 3,
#  'gasfundy@enron.com': inf,
#  'lucy.ortiz@enron.com': 4,
#  'jeff.andrews@enron.com': inf,
#  'agustin.perez@enron.com': 4,
#  'enron.services@enron.com': inf,
#  'amanda.rybarski@enron.com': 3,
#  'chuck.ames@enron.com': 3,
#  'jonathan.mckay@enron.com': 2,
#  'f..brawner@enron.com': 1,
#  '40enron@enron.com': 6,
#  'All_ENA_EGM_EIM@ENRON': 7,
#  'eric.boyt@enron.com': 5,
#  'sonya.johnson@enron.com': inf,
#  'rudy.acevedo@enron.com': 4,
#  'suzanne.adams@enron.com': inf,
#  'fraser.allen@enron.com': inf,
#  'denis.bajolle@enron.com': 4,
#  'jozsef.balogh@enron.com': inf,
#  'don.baughman@enron.com': 3,
#  'david.baumbach@enron.com': 3,
#  'gregor.baumerich@enron.com': inf,
#  'kimberlee.bennick@enron.com': 8,
#  'corry.bentley@enron.com': 4,
#  'jason.biever@enron.com': 4,
#  'justin.boyd@enron.com': inf,
#  'greg.brazaitis@enron.com': inf,
#  'rebecca.cantrell@enron.com': 6,
#  'michelle.cash@enron.com': 6,
#  'jon.chapman@enron.com': inf,
#  'winston.cheng@enron.com': inf,
#  'dustin.collins@enron.com': 4,
#  'harry.collins@enron.com': 8,
#  'kayne.coulter@enron.com': 4,
#  'natasha.danilochkina@enron.com': inf,
#  'derek.davies@enron.com': 3,
#  'paul.dawson@enron.com': inf,
#  'paul.devries@enron.com': inf,
#  'trang.dinh@enron.com': inf,
#  'john.disturnal@enron.com': 3,
#  'jeff.donahue@enron.com': 6,
#  'mary.dove@enron.com': inf,
#  'lon.draper@enron.com': 4,
#  'ian.dundas@enron.com': inf,
#  'jarek.dybowski@enron.com': 6,
#  'david.eubanks@enron.com': inf,
#  'farzad.farhangnia@enron.com': inf,
#  'jose.figueira@enron.com': inf,
#  'genia.fitzgerald@enron.com': 8,
#  'shawna.flynn@enron.com': 8,
#  'eric.gillaspie@enron.com': 8,
#  'hector.godoy@enron.com': inf,
#  'joe.gold@enron.com': 4,
#  'john.gorman@enron.com': inf,
#  'jin.guo@enron.com': inf,
#  'mary.hain@enron.com': 5,
#  'jai.hawker@enron.com': inf,
#  'mary.heinitz@enron.com': 7,
#  'jenny.helton@enron.com': inf,
#  'jonathan.hoff@enron.com': 4,
#  'erik.hokmark@enron.com': inf,
#  'jim.homco@enron.com': 5,
#  'mary.hopkins@enron.com': inf,
#  'dan.hyvl@enron.com': 8,
#  'neil.jackson@enron.com': inf,
#  'victoria.johnson@enron.com': inf,
#  'deb.korkmas@enron.com': 7,
#  'dean.laurent@enron.com': 4,
#  'doug.leach@enron.com': inf,
#  'elsie.lew@enron.com': 4,
#  'miles.lidsey@enron.com': inf,
#  'homer.lin@enron.com': inf,
#  'gretchen.lotz@enron.com': 4,
#  'derek.lynn@enron.com': inf,
#  'dan.lyons@enron.com': 8,
#  'iona.maclean@enron.com': inf,
#  'posey.martinez@enron.com': 5,
#  'elizabeth.mccarthy@enron.com': inf,
#  'kelly.mccoy@enron.com': inf,
#  'fred.mitro@enron.com': inf,
#  'eric.moon@enron.com': 4,
#  'janet.moore@enron.com': 8,
#  'janice.moore@enron.com': 8,
#  'russell.murrell@enron.com': inf,
#  'gerald.nemec@enron.com': 7,
#  'florian.neubauer@enron.com': inf,
#  'matthew.nicholas@enron.com': inf,
#  'linda.noske@enron.com': 8,
#  'jiri.novotny@enron.com': inf,
#  'mary.ogden@enron.com': 7,
#  'grant.oh@enron.com': 4,
#  'john.oliver@enron.com': inf,
#  'jitendra.patel@enron.com': 4,
#  'gregg.penman@enron.com': 4,
#  'debra.perlingiere@enron.com': 8,
#  'john.peyton@enron.com': inf,
#  'david.redmond@enron.com': inf,
#  'louis.redshaw@enron.com': inf,
#  'cooper.richey@enron.com': 4,
#  'michael.rosen@enron.com': inf,
#  'jivko.savov@enron.com': 8,
#  'l..schrab@enron.com': 4,
#  'eric.shaw@enron.com': 6,
#  'tom.shelton@enron.com': 5,
#  'john.sherriff@enron.com': 5,
#  'gareth.simpson@enron.com': inf,
#  'michael.slade@enron.com': inf,
#  'ian.sloman@enron.com': inf,
#  'fletcher.sturm@enron.com': 3,
#  'john.suarez@enron.com': 3,
#  'fred.tan@enron.com': inf,
#  'hala.tayyarah@enron.com': inf,
#  'garrett.tripp@enron.com': 4,
#  'steve.vavrik@enron.com': inf,
#  'robert.walker@enron.com': 8,
#  'stacey.white@enron.com': 6,
#  'chris.wiebe@enron.com': inf,
#  'r..wiesepape@enron.com': inf,
#  'doug.wood@enron.com': inf,
#  'kay.young@enron.com': 8,
#  'john.zufferli@enron.com': 3,
#  'k..allen@enron.com': 3,
#  'f..keavey@enron.com': 2,
#  'a..martin@enron.com': 2,
#  'w..pereira@enron.com': 3,
#  's..shively@enron.com': 3,
#  'tara.sweitzer@enron.com': 4,
#  'veronica.espinoza@enron.com': inf,
#  'r..brackett@enron.com': inf,
#  's..bradford@enron.com': 3,
#  'r..conner@enron.com': inf,
#  'patrick.hanse@enron.com': 4,
#  'kelly.lovvorn@enron.com': inf,
#  'ann.murphy@enron.com': 5,
#  "schultz'.'kyle@enron.com": inf,
#  'kim.theriot@enron.com': 6,
#  'greg.wolfe@enron.com': 3,
#  'christian.yoder@enron.com': 8,
#  "origination'.'black@enron.com": inf,
#  "paul'.'choi@enron.com": inf,
#  "fairley'.'david@enron.com": inf,
#  'j..miller@enron.com': inf,
#  'steve.neal@enron.com': inf,
#  's..olinger@enron.com': 3,
#  'h..otto@enron.com': 3,
#  'david.parquet@enron.com': inf,
#  'beth.perlman@enron.com': inf,
#  'bo.petersen@enron.com': inf,
#  's..pollan@enron.com': 4,
#  'a..price@enron.com': inf,
#  'daniel.reck@enron.com': inf,
#  'leslie.reeves@enron.com': inf,
#  'brian.riley@enron.com': inf,
#  'suzy.robey@enron.com': inf,
#  'hpl.schneider@enron.com': inf,
#  "jim'.'schwieger@enron.com": inf,
#  'a..shankman@enron.com': 5,
#  'mary.smith@enron.com': 6,
#  'd..sorenson@enron.com': inf,
#  'p..south@enron.com': 3,
#  'a..allen@enron.com': inf,
#  'd..baughman@enron.com': 3,
#  "sally'.'beck@enron.com": inf,
#  'bob.bowen@enron.com': 3,
#  'craig.breslau@enron.com': 3,
#  "gary'.'bryan@enron.com": inf,
#  'cary.carrabine@enron.com': inf,
#  "larry'.'cash@enron.com": inf,
#  'brad.coleman@enron.com': inf,
#  "angie'.'collins@enron.com": inf,
#  'robert.cotten@enron.com': inf,
#  'james.ducote@enron.com': inf,
#  'michael.etringer@enron.com': 4,
#  'h..foster@enron.com': 3,
#  'sheila.glover@enron.com': inf,
#  "julie'.'gomez@enron.com": inf,
#  'lance.halgren@enron.com': inf,
#  "cortez'.'nicole@enron.com": inf,
#  "thomas'.'martin@enron.com": inf,
#  'stuart.staley@enron.com': inf,
#  'jung-suk.suh@enron.com': inf,
#  'mark.taylor@enron.com': 5,
#  'm..tholt@enron.com': 3,
#  'jake.thomas@enron.com': 4,
#  'janelle.scheuer@enron.com': 4,
#  'n..gilbert@enron.com': 3,
#  "lucci'.'paul@enron.com": inf,
#  "joseph'.'graham@enron.com": inf,
#  'lisa.mellencamp@enron.com': 6,
#  'tana.jones@enron.com': 8,
#  'shonnie.daniel@enron.com': 5,
#  'barbara.gray@enron.com': 5,
#  'steve.van@enron.com': inf,
#  "peggy'.'banczak@enron.com": inf,
#  'mary.cook@enron.com': 8,
#  'sandi.braband@enron.com': 8,
#  'elizabeth.white@enron.com': inf,
#  'carol.st@enron.com': inf,
#  'nathan.hlavaty@enron.com': inf,
#  'melissa.graves@enron.com': inf,
#  'susan.smith@enron.com': inf,
#  'l..taylor@enron.com': inf,
#  'p..reinhardt@enron.com': inf,
#  "adam'.'gross@enron.com": inf,
#  'h..lewis@enron.com': 3,
#  "lucy'.'ortiz@enron.com": inf,
#  'barend.vanderhorst@enron.com': inf,
#  'james.barker@enron.com': inf,
#  "driscoll'.'marde@enron.com": inf,
#  "timothy'.'ray@enron.com": inf,
#  "monica'.'roberts@enron.com": inf,
#  "james'.'shirley@enron.com": inf,
#  'stacy.dickson@enron.com': 8,
#  'linda.ewing@enron.com': inf,
#  "john'.'grass@enron.com": inf,
#  'joanie.ngo@enron.com': inf,
#  'r..lilly@enron.com': inf,
#  "lisa'.'csikos@enron.com": inf,
#  'j..hanson@enron.com': 3,
#  'katherine.herrera@enron.com': inf,
#  'kevin.bosse@enron.com': 3,
#  'william.stuart@enron.com': inf,
#  'isabel.resendez@enron.com': 5,
#  'drew.hill@enron.com': 5,
#  'sheetal.patel@enron.com': 4,
#  "martin.o'leary@enron.com": inf,
#  'souad.mahmassani@enron.com': 4,
#  'john.singer@enron.com': inf,
#  'jay.knoblauh@enron.com': inf,
#  "ned'.'higgins@enron.com": inf,
#  'dan.mccairns@enron.com': inf,
#  'andrew.greer@enron.com': 4,
#  "george'.'hope@enron.com": inf,
#  "daniel'.'diamond@enron.com": inf,
#  "teresa'.'mandola@enron.com": inf,
#  'andrea.hauser@enron.com': inf,
#  "justin'.'rostant@enron.com": inf,
#  'lisa.gillette@enron.com': 4,
#  "harry'.'bucalo@enron.com": inf,
#  "bryan'.'hull@enron.com": inf,
#  "bill'.'kyle@enron.com": inf,
#  'gerald.lofton@enron.com': inf,
#  "marshall'.'cheryl@enron.com": inf,
#  'jack.simunek@enron.com': inf,
#  'candy.bywaters@enron.com': inf,
#  'kenneth.kaase@enron.com': inf,
#  'ron.green@enron.com': inf,
#  'jennifer.blay@enron.com': inf,
#  'audrey.cook@enron.com': 5,
#  'teresa.seibel@enron.com': inf,
#  'dennis.benevides@enron.com': inf,
#  'tracy.ngo@enron.com': inf,
#  'joanne.harris@enron.com': inf,
#  "'rmservices'@enron.com": inf,
#  "timothy'.'hamilton@enron.com": inf,
#  'todd.lambert@enron.com': inf,
#  "morgan'.'babin@enron.com": inf,
#  'paul.tate@enron.com': 4,
#  'laura.arnold@enron.com': inf,
#  'jay.blaine@enron.com': 4,
#  'zarin.imam@enron.com': inf,
#  'alain.diza@enron.com': 4,
#  "sharon'.'hausinger@enron.com": inf,
#  "jeff'.'coates@enron.com": inf,
#  'christina.bangle@enron.com': inf,
#  'rhonda.smith@enron.com': 4,
#  'amanda.boettcher@enron.com': inf,
#  'tom.moran@enron.com': 5,
#  'sherry.pendegraft@enron.com': 4,
#  'lisa.valderrama@enron.com': 5,
#  'tim.weithman@enron.com': inf,
#  'kyle.griffin@enron.com': inf,
#  'lester.rawson@enron.com': 5,
#  'm.hall@enron.com': 4,
#  "kathryn'.'bussell@enron.com": inf,
#  'bryce.baxter@enron.com': 3,
#  'bernard.dahanayake@enron.com': inf,
#  'richard.deming@enron.com': inf,
#  'janie.aguayo@enron.com': inf,
#  'derek.bailey@enron.com': 3,
#  'diane.anderson@enron.com': 3,
#  'joe.hunter@enron.com': 4,
#  'ellen.wallumrod@enron.com': 4,
#  'lisa.lees@enron.com': 4,
#  'stephanie.sever@enron.com': 4,
#  'daniel.salinas@enron.com': 4,
#  'josephine.logan@enron.com': inf,
#  'joni.fisher@enron.com': inf,
#  'meredith.eggleston@enron.com': inf,
#  'vladimir.gorny@enron.com': 4,
#  'cindy.vachuska@enron.com': inf,
#  'angelo.miroballi@enron.com': inf,
#  'jess.hewitt@enron.com': inf,
#  'melissa.ratnala@enron.com': inf,
#  'w..vickers@enron.com': 5,
#  'rumaldo.lopez@enron.com': inf,
#  'marc.de@enron.com': inf,
#  'debra.young@enron.com': inf,
#  'jeff.arnold@enron.com': inf,
#  'ann.johnson@enron.com': inf,
#  'ruthann.frausto@enron.com': inf,
#  'mark.koenig@enron.com': 5,
#  'robert.geheb@enron.com': inf,
#  'santiago.garcia@enron.com': 4,
#  'vineet.arora@enron.com': inf,
#  'jan.sutherland@enron.com': 4,
#  'josh.mayes@enron.com': inf,
#  'geraldine.irvine@enron.com': 4,
#  'rebecca.ford@enron.com': inf,
#  'j..brewer@enron.com': inf,
#  'suzanne.christiansen@enron.com': 3,
#  'yolanda.cordova-gilbert@enron.com': inf,
#  'charles.weldon@enron.com': 3,
#  'jason.wolfe@enron.com': 4,
#  'robert.virnau@enron.com': inf,
#  'tyrone.brown@enron.com': inf,
#  'amy.villasenor@enron.com': inf,
#  'larry.fenstad@enron.com': inf,
#  'lynne.dix@enron.com': inf,
#  'morris.brassfield@enron.com': 6,
#  'shelly.mendel@enron.com': 3,
#  'ted.evans@enron.com': inf,
#  'bill.berkeland@enron.com': inf,
#  'dina.snow@enron.com': 4,
#  'a..ryan@enron.com': inf,
#  'lynn.johnson@enron.com': inf,
#  'kurt.lindahl@enron.com': inf,
#  'thane.twiggs@enron.com': inf,
#  'mike.thomas@enron.com': inf,
#  'randal.maffett@enron.com': 10,
#  'm..grace@enron.com': inf,
#  'ruth.concannon@enron.com': 4,
#  'daniel.lisk@enron.com': 4,
#  'mark.adleman@enron.com': inf,
#  'tushar.dhruv@enron.com': inf,
#  'sandy.olitsky@enron.com': inf,
#  'rinetia.turner@enron.com': inf,
#  'lance.schuler@enron.com': inf,
#  'kathie.grabstald@enron.com': inf,
#  'mark.breese@enron.com': 4,
#  'a..terlip@enron.com': inf,
#  'hillary.mack@enron.com': inf,
#  'phil.demoes@enron.com': 5,
#  'steven.curlee@enron.com': inf,
#  'ann.matson@enron.com': inf,
#  'gil.muhl@enron.com': 4,
#  'nelson.ferries@enron.com': 4,
#  'nick.moshou@enron.com': inf,
#  'shawn.franks@enron.com': inf,
#  'david.jones@enron.com': 4,
#  'eric.thode@enron.com': inf,
#  'clint.shay@enron.com': inf,
#  'darrin.morris@enron.com': inf,
#  'mark.jordan@enron.com': inf,
#  'pete.releford@enron.com': inf,
#  'robin.chavez@enron.com': inf,
#  'joel.valdez@enron.com': inf,
#  'khalid.makiya@enron.com': inf,
#  'mark.garrett@enron.com': inf,
#  'nathan.childs@enron.com': inf,
#  'sheyi.joseph@enron.com': inf,
#  'tavares.johnson@enron.com': inf,
#  'brandon.parker@enron.com': inf,
#  'jaime.gonzales@enron.com': inf,
#  'steve.herron@enron.com': inf,
#  'dolph.selten@enron.com': inf,
#  'julie.clyatt@enron.com': 3,
#  'darren.adamik@enron.com': 3,
#  'p..adams@enron.com': 3,
#  'habib.ahsan@enron.com': 3,
#  'd.alexander@enron.com': 3,
#  'diana.allen@enron.com': 3,
#  'jason.althaus@enron.com': 3,
#  'susan.amador@enron.com': 3,
#  'amanullah.aman@enron.com': 3,
#  'sherry.anastas@enron.com': 3,
#  'dan.arellano@enron.com': 3,
#  'ravi.arumbakkam@enron.com': 3,
#  'chris.austin@enron.com': 3,
#  'luis.aybar@enron.com': 3,
#  'natalie.baker@enron.com': 3,
#  'arun.balasundaram@enron.com': 3,
#  'ted.ballinger@enron.com': 3,
#  'charles.ballmer@enron.com': 3,
#  'michael.barber@enron.com': 3,
#  'eric.bass@enron.com': 3,
#  'nilay.basu@enron.com': 3,
#  'chris.behney@enron.com': 3,
#  'cedric.belt@enron.com': 3,
#  'troy.beyer@enron.com': 3,
#  'randy.bhatia@enron.com': 3,
#  'jae.black@enron.com': 3,
#  'gary.bode@enron.com': 3,
#  'ryan.brennan@enron.com': 3,
#  'karen.buckley@enron.com': 3,
#  'victor.bulbes@enron.com': 3,
#  'simon.burgess@enron.com': 3,
#  'janine.cashin@enron.com': 3,
#  'michael.castillo@enron.com': 3,
#  'john.cheng@enron.com': 3,
#  'diana.cioffi@enron.com': 3,
#  'kristen.clause@enron.com': 3,
#  'frank.coles@enron.com': 3,
#  'paige.cox@enron.com': 3,
#  'a..cummings@enron.com': 3,
#  'amanda.curless@enron.com': 3,
#  'neil.davies@enron.com': 3,
#  'roberto.deleon@enron.com': 3,
#  'janet.devereaux@enron.com': 3,
#  'dan.dietrich@enron.com': 3,
#  'michael.dolan@enron.com': 3,
#  'keith.dziadek@enron.com': 3,
#  'clay.elliott@enron.com': 3,
#  'frank.ermis@enron.com': 3,
#  'j..ewing@enron.com': 3,
#  'amy.fitzpatrick@enron.com': 3,
#  'bryant.frihart@enron.com': 3,
#  'l..gay@enron.com': 3,
#  'doug.gichana@enron.com': 3,
#  'c..giron@enron.com': 3,
#  'c..gossett@enron.com': 3,
#  'marlin.gubser@enron.com': 3,
#  'claudia.guerra@enron.com': 3,
#  'joe.hall@enron.com': 3,
#  'mark.hall@enron.com': 3,
#  'd..hogan@enron.com': 3,
#  'james.hungerford@enron.com': 3,
#  'charles.jacobs@enron.com': 3,
#  'matthew.james@enron.com': 3,
#  'tammy.jaquet@enron.com': 3,
#  'anthony.jarrett@enron.com': 3,
#  'james.johnston@enron.com': 4,
#  'brad.jones@enron.com': 3,
#  'monte.jones@enron.com': 3,
#  'shivshankar.kandavelu@enron.com': 3,
#  'bill.knox@enron.com': 3,
#  'brian.larkin@enron.com': 3,
#  'rick.le@enron.com': 3,
#  'kathy.link@enron.com': 3,
#  'kori.loibl@enron.com': 3,
#  'm..love@enron.com': 3,
#  'danielle.marcinkowski@enron.com': 3,
#  'bob.mcauliffe@enron.com': 3,
#  'errol.mclaughlin@enron.com': 3,
#  'darren.mcnair@enron.com': 3,
#  'jason.mcnair@enron.com': 3,
#  'genaro.mendoza@enron.com': 3,
#  'bruce.mills@enron.com': 3,
#  'l..mims@enron.com': 3,
#  'g..moore@enron.com': 3,
#  'daniel.muschar@enron.com': 3,
#  'donnie.myers@enron.com': 3,
#  'acey.nash@enron.com': 3,
#  'john.oh@enron.com': 3,
#  'matthew.olney@enron.com': 3,
#  'michael.olsen@enron.com': 3,
#  'kari.oquinn@enron.com': 3,
#  "ryan.o'rourke@enron.com": 3,
#  'david.oxley@enron.com': 2,
#  'scott.palmer@enron.com': 3,
#  'stephen.perich@enron.com': 3,
#  'richard.pinion@enron.com': 3,
#  'faheem.qavi@enron.com': 3,
#  'dutch.quigley@enron.com': 3,
#  'edward.ray@enron.com': 3,
#  'trey.rhodes@enron.com': 3,
#  'jenny.rub@enron.com': 3,
#  'scott.shishido@enron.com': 3,
#  'steve.shortt@enron.com': 3,
#  'john.shupak@enron.com': 3,
#  'jeanie.slone@enron.com': 3,
#  'bruce.smith@enron.com': 3,
#  'mathew.smith@enron.com': 3,
#  'cathy.sprowls@enron.com': 3,
#  'micah.staggs@enron.com': 3,
#  'david.steiner@enron.com': 3,
#  'patti.sullivan@enron.com': 3,
#  'joseph.taylor@enron.com': 3,
#  'todd.thelen@enron.com': 3,
#  'benjamin.thompson@enron.com': 3,
#  'brent.tiner@enron.com': 3,
#  'barry.tycholiz@enron.com': 3,
#  'carlos.uribe@enron.com': 3,
#  'john.valdes@enron.com': 3,
#  'leah.van@enron.com': 3,
#  'laura.vargas@enron.com': 3,
#  'frank.vickers@enron.com': 3,
#  'melissa.videtto@enron.com': 3,
#  'laura.vuittonet@enron.com': 3,
#  'enron.announcement@enron.com': inf,
#  'enron.chairman@enron.com': inf,
#  'henry.safety@enron.com': inf,
#  'general.announcement@enron.com': inf,
#  'victor.lamadrid@enron.com': 4,
#  'l..kelly@enron.com': 4,
#  'jeff.royed@enron.com': 3,
#  'michael.yowman@enron.com': inf,
#  'eSource@ENRON': inf,
#  'announcements.enron@enron.com': inf,
#  'dl-ga-all_domestic@enron.com': inf,
#  'dawn.mcdonald@enron.com': 5,
#  'steve.wang@enron.com': 2,
#  'traders.dl-netco@enron.com': 3,
#  'traders.eol@enron.com': 6,
#  'brawner@enron.com': inf,
#  'feedback@intcx.com': inf,
#  'iceuserslist@list.intcx.com': inf,
#  'robert.allwein@enron.com': 3,
#  'shanna.boudreaux@enron.com': 4,
#  'tamara.carter@enron.com': 4,
#  'joann.collins@enron.com': 4,
#  'stephanie.erwin@enron.com': 4,
#  'clarissa.garcia@enron.com': 4,
#  'steve.gillespie@enron.com': 4,
#  'lia.halstead@enron.com': 4,
#  'meredith.homco@enron.com': 4,
#  'kelly.loocke@enron.com': 4,
#  'scott.loving@enron.com': 5,
#  'chris.ordway@enron.com': 4,
#  'michael.pritchard@enron.com': 4,
#  'dan.prudenti@enron.com': 4,
#  'robert.ramirez@enron.com': 4,
#  'christina.sanchez@enron.com': 4,
#  'tracy.wood@enron.com': 4,
#  'l..driscoll-ernest@enron.com': 4,
#  'robert.superty@enron.com': 4,
#  's..theriot@enron.com': 4,
#  'c..aucoin@enron.com': 4,
#  'jungsuk.suh@enron.com': inf,
#  'leonidas.savvas@enron.com': 4,
#  'alejandra.chavez@enron.com': 4,
#  'darren.espey@enron.com': 4,
#  'kulvinder.fowler@enron.com': 3,
#  'luchas.johnson@enron.com': 3,
#  'hal.mckinney@enron.com': 3,
#  'ashley.worthing@enron.com': 3,
#  'suzanne.calcagno@enron.com': 2,
#  'dl-ga-all_domestic2@enron.com': inf,
#  'cocob@pdq.net': 2,
#  'dl-ga-all_enron_worldwide1@enron.com': inf,
#  'jr..legal@enron.com': inf,
#  'dl-ga-all_enron_worldwide3@enron.com': inf,
#  'alex.saldana@enron.com': 4,
#  'brandee.jackson@enron.com': 4,
#  'heather.choate@enron.com': 4,
#  'jesse.villarreal@enron.com': 4,
#  'dl-ga-all_netco@enron.com': inf,
#  'coo.jeff@enron.com': inf,
#  'j..legler@enron.com': 3,
#  'a..gomez@enron.com': 3,
#  'brian.redmond@enron.com': 3,
#  'gary.bryan@enron.com': 3,
#  'jd.buss@enron.com': 3,
#  'j..farmer@enron.com': 3,
#  'bryan.hull@enron.com': 3,
#  'joe.parks@enron.com': 3,
#  'chance.rabon@enron.com': 2,
#  'patrick.ryder@enron.com': 3,
#  'd..winfree@enron.com': 3,
#  'sbrawne@ect.enron.com': 3,
#  'shauywn.smith@enron.com': 4,
#  'jim.willis@enron.com': 5,
#  't..zivley@enron.com': 5,
#  'lindsay.culotta@enron.com': 4,
#  'e.murrell@enron.com': 4,
#  'patrick.tucker@enron.com': 4,
#  'gary.taylor@enron.com': 4,
#  'chris.walker@enron.com': 4,
#  'virawan.yawapongsiri@enron.com': 4,
#  'joan.collins@enron.com': 3,
#  'a..roberts@enron.com': 3,
#  'jose.marquez@enron.com': 3,
#  'kennedy.kathleen@enron.com': 4,
#  'newland.kody@enron.com': 4,
#  'caldwell.sue@enron.com': 4,
#  'schnitzer.susan@enron.com': 4,
#  'chairman.ken@enron.com': inf,
#  'dl-ga-all_enron_worldwide@enron.com': inf,
#  'rachel.bryant@enron.com': 4,
#  'bart.burk@enron.com': 3,
#  'kathryn.bussell@enron.com': 4,
#  'tetteh.canacoo@enron.com': 4,
#  'catalina.cardenas@enron.com': 4,
#  'brandon.cavazos@enron.com': 4,
#  'amy.cavazos@enron.com': 4,
#  'bonnie.chang@enron.com': 4,
#  'sheila.chang@enron.com': 4,
#  'elena.chilkina@enron.com': 4,
#  'lindon.chiu@enron.com': 4,
#  'shawn.chmil@enron.com': 4,
#  'andrea.clements@enron.com': 4,
#  'venita.coleman@enron.com': 4,
#  'angie.collins@enron.com': 4,
#  'wes.colwell@enron.com': 4,
#  'karla.compean@enron.com': 4,
#  'chris.cramer@enron.com': 4,
#  'jason.panos@enron.com': 4,
#  'troy.denetsosie@enron.com': 4,
#  'joseph.des@enron.com': 4,
#  'l..dinari@enron.com': 4,
#  'jad.doan@enron.com': 4,
#  'david.dronet@enron.com': 4,
#  'lisa.druzbik@enron.com': 4,
#  'gwen.espree@enron.com': 4,
#  'brian.falik@enron.com': 4,
#  'chris.figueroa@enron.com': 4,
#  'loftus.fitzwater@enron.com': 4,
#  'b..fleming@enron.com': 4,
#  'h..fletcher@enron.com': 4,
#  'neithard.foley@enron.com': 4,
#  'keith.fraley@enron.com': 4,
#  'carole.frank@enron.com': 4,
#  'scott.franklin@enron.com': 4,
#  'theresa.franklin@enron.com': 4,
#  'cynthia.franklin@enron.com': 4,
#  'ben.freeman@enron.com': 4,
#  'amy.freeman@enron.com': 4,
#  'shalesh.ganjoo@enron.com': 4,
#  'maria.garza@enron.com': 4,
#  'jeff.gerl@enron.com': 4,
#  'tammy.gilmore@enron.com': 4,
#  'alexia.gonzales@enron.com': 4,
#  'e.grannen@enron.com': 4,
#  'george.grant@enron.com': 4,
#  'shane.green@enron.com': 4,
#  'paul.gregory@enron.com': 4,
#  'donna.greif@enron.com': 4,
#  'shannon.groenewold@enron.com': 4,
#  'l..hall@enron.com': 4,
#  'mason.hamlin@enron.com': 4,
#  'kimberly.hardy@enron.com': 4,
#  'darian.hawkins@enron.com': 4,
#  'craig.hawkins@enron.com': 4,
#  'helen.haynes@enron.com': 4,
#  'daniel.haynes@enron.com': 4,
#  'tamika.hebert@enron.com': 4,
#  'a.hernandez@enron.com': 4,
#  'l..hernandez@enron.com': 4,
#  'fernando.herrera@enron.com': 4,
#  'lisa.hesse@enron.com': 4,
#  'p..hewitt@enron.com': 4,
#  'wendy.hiatt@enron.com': 4,
#  'nick.hiemstra@enron.com': 4,
#  'ned.higgins@enron.com': 4,
#  'chris.hilgert@enron.com': 4,
#  'ryan.hinze@enron.com': 4,
#  'stephanie.hopkins@enron.com': 4,
#  'jonathan.horne@enron.com': 4,
#  'sarah.hotze@enron.com': 4,
#  'peter.hoyt@enron.com': 4,
#  'george.huan@enron.com': 4,
#  'jason.huang@enron.com': 4,
#  'clinton.hurt@enron.com': 4,
#  'monica.hwang@enron.com': 4,
#  'chris.hyde@enron.com': 4,
#  'angela.hylton@enron.com': 4,
#  'jennifer.jennings@enron.com': 4,
#  'exec.jones@enron.com': 4,
#  'melissa.jones@enron.com': 4,
#  'dayem.khandker@enron.com': 4,
#  'lisa.kinsey@enron.com': 4,
#  'mark.knippa@enron.com': 4,
#  'sladana-anna.kulic@enron.com': 4,
#  'milen.kurdov@enron.com': 4,
#  'tori.kuykendall@enron.com': 3,
#  'kirk.lenart@enron.com': 4,
#  'barry.lewis@enron.com': 4,
#  'jozef.lieskovsky@enron.com': 4,
#  'kelli.little@enron.com': 3,
#  'jeremy.lo@enron.com': 4,
#  'laura.luce@enron.com': 4,
#  'christie.manck@enron.com': 4,
#  'jabari.martin@enron.com': 4,
#  'martin.thomas@enron.com': 4,
#  'jennifer.martinez@enron.com': 4,
#  'robert.mattice@enron.com': 4,
#  'michael.mccaskin@enron.com': 4,
#  'lisa.mcclendon@enron.com': 4,
#  'chris.meyer@enron.com': 4,
#  'jim.meyn@enron.com': 4,
#  'david.michels@enron.com': 4,
#  'andrew.migliano@enron.com': 4,
#  'andrew.miles@enron.com': 4,
#  'kevin.miller@enron.com': 4,
#  'jana.mills@enron.com': 4,
#  'jeffrey.molinaro@enron.com': 4,
#  'john.morris@enron.com': 4,
#  't..muzzy@enron.com': 4,
#  'junellen.neese@enron.com': 4,
#  'michelle.nelson@enron.com': 4,
#  'lisbet.newton@enron.com': 4,
#  'thinh.nguyen@enron.com': 4,
#  "justin.o'malley@enron.com": 4,
#  'jennie.pai@enron.com': 4,
#  'neeran.pathak@enron.com': 4,
#  'biliana.pehlivanova@enron.com': 4,
#  'cora.pendergrass@enron.com': 4,
#  'christopher.pernoud@enron.com': 4,
#  'denver.plachy@enron.com': 4,
#  'stephen.plauche@enron.com': 4,
#  'phil.polsky@enron.com': 4,
#  'jessica.presas@enron.com': 4,
#  'daniel.quezada@enron.com': 4,
#  'eva.rainer@enron.com': 4,
#  'david.ratliff@enron.com': 4,
#  'pauline.reyes@enron.com': 4,
#  'sean.riordan@enron.com': 4,
#  'chaun.roberts@enron.com': 4,
#  'linda.roberts@enron.com': 4,
#  'ruby.robinson@enron.com': 4,
#  'araceli.romero@enron.com': 4,
#  'justin.rostant@enron.com': 4,
#  'michael.salinas@enron.com': 4,
#  'lauren.schlesinger@enron.com': 4,
#  'm..scott@enron.com': 4,
#  'rahul.seksaria@enron.com': 4,
#  'user.shah@enron.com': 4,
#  'r..shepperd@enron.com': 4,
#  'kristann.shireman@enron.com': 4,
#  'digna.showers@enron.com': 4,
#  'critz.smith@enron.com': 4,
#  'f..smith@enron.com': 4,
#  'mark.smith@enron.com': 4,
#  'joseph.smith@enron.com': 4,
#  'william.smith@enron.com': 4,
#  'melissa.solis@enron.com': 4,
#  'elizabeth.soto@enron.com': 4,
#  'gulay.soykok@enron.com': 4,
#  'walter.spiegelhauer@enron.com': 4,
#  'stephanie.stehling@enron.com': 4,
#  ...}
