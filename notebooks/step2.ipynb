# %%
import os
from utils.graph import Grafo

# %%
grafo = Grafo.load_pickled_graph("../graph/graph.pkl")

# %%
# * a. Número de vertices:
print(f"Número de vértices: {grafo.ordem}")

# * b. Número de arestas:
print(f"Número de arestas: {grafo.tamanho}")

# * c. ignorada, pois vértices isolados não foram criados

# * d. 20 indivíduos que possuem maior grau de saída
maiores_entrada = grafo.maiores_graus_entrada(20).items()
print("Vertices com maiores grau de entrada:")
i = 1
for vertice, valor in maiores_entrada:
    print(f"{i}: {vertice} - {valor}")
    i += 1

print("--------------------------------------------------------")

# * d. 20 indivíduos que possuem maior grau de entrada 
maiores_saida = grafo.maiores_graus_saida(20).items()
print("Vertices com maiores grau de saida")
i = 1
for vertice, valor in maiores_saida:
    print(f"{i}: {vertice} - {valor}")
    i += 1
# Out:
# Número de vértices: 7130
# Número de arestas: 15746
# Vertices com maiores grau de entrada:
# 1: james.derrick@enron.com - 164
# 2: lindy.donoho@enron.com - 112
# 3: mike.carson@enron.com - 109
# 4: martin.cuilla@enron.com - 81
# 5: drew.fossum@enron.com - 67
# 6: f..brawner@enron.com - 60
# 7: mcuilla@enron.com - 45
# 8:
# 	lindy.donoho@enron.com - 45
# 9: steven.harris@enron.com - 43
# 10: scott.neal@enron.com - 40
# 11: kimberly.watson@enron.com - 37
# 12: tk.lohman@enron.com - 36
# 13: lorraine.lindberg@enron.com - 33
# 14: michelle.lokay@enron.com - 32
# 15:
# 	james.derrick@enron.com - 30
# 16: rob.walls@enron.com - 28
# 17: jan.moore@enron.com - 28
# 18:
# 	steven.harris@enron.com - 28
# 19: shelley.corman@enron.com - 27
# 20:
# 	lorraine.lindberg@enron.com - 26
# --------------------------------------------------------
# Vertices com maiores grau de saida
# 1: andrew.wu@enron.com - 630
# 2: daniel.muschar@enron.com - 428
# 3: julie.clyatt@enron.com - 326
# 4: neil.davies@enron.com - 323
# 5: technology.enron@enron.com - 289
# 6: lorna.brennan@enron.com - 289
# 7: drew.fossum@enron.com - 247
# 8: david.forster@enron.com - 246
# 9: veronica.espinoza@enron.com - 238
# 10: darron.giron@enron.com - 238
# 11: jae.black@enron.com - 215
# 12: james.derrick@enron.com - 214
# 13: tthoman@aga.org - 211
# 14: tammie.schoppe@enron.com - 196
# 15: david.oxley@enron.com - 187
# 16: shelley.corman@enron.com - 171
# 17: janet.butler@enron.com - 168
# 18: dennis.lee@enron.com - 165
# 19: rhonda.denton@enron.com - 164
# 20: danielle.marcinkowski@enron.com - 159
